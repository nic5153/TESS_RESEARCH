# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020hao', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd4\lc_discovery\lc_2020hao_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020gei', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam1_ccd4\lc_discovery\lc_2020gei_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fuc', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd1\lc_discovery\lc_2020fuc_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fuf', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam4_ccd3\lc_discovery\lc_2020fuf_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fzk', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam4_ccd3\lc_discovery\lc_2020fzk_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fbt', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam2_ccd2\lc_discovery\lc_2020fbt_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020hkv', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam4_ccd1\lc_discovery\lc_2020hkv_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fli', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam2_ccd1\lc_discovery\lc_2020fli_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020frs', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam4_ccd2\lc_discovery\lc_2020frs_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fjz', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd3\lc_discovery\lc_2020fjz_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fmz', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam4_ccd1\lc_discovery\lc_2020fmz_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fwt', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd3\lc_discovery\lc_2020fwt_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fac', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd1\lc_discovery\lc_2020fac_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fjs', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam2_ccd1\lc_discovery\lc_2020fjs_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020gkt', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd3\lc_discovery\lc_2020gkt_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fik', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd2\lc_discovery\lc_2020fik_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fwi', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam4_ccd3\lc_discovery\lc_2020fwi_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fsk', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam2_ccd4\lc_discovery\lc_2020fsk_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020hhc', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam2_ccd1\lc_discovery\lc_2020hhc_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fad', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd4\lc_discovery\lc_2020fad_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020har', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam4_ccd3\lc_discovery\lc_2020har_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020gbb', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd2\lc_discovery\lc_2020gbb_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return
    
    #Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020fyk', fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    #Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector23\cam3_ccd3\lc_discovery\lc_2020fyk_cleaned.txt"
    #Specify the delimiter used in the .txt file
    delimiter = r"\s+"
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

#probable supernova
