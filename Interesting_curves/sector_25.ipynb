# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020kda', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam2_ccd3\lc_discovery\lc_2020kda_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020kyi', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam2_ccd3\lc_discovery\lc_2020kyi_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

def plot_light_curve_with_fft(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Remove the mean magnitude to eliminate the DC component
    magnitude_mean = np.mean(df['Magnitude'])
    df['Magnitude'] -= magnitude_mean
    
    # Compute the Fourier Transform of the magnitude
    mag_fft = np.fft.fft(df['Magnitude'])
    freqs = np.fft.fftfreq(len(df['Time']), df['Time'][1] - df['Time'][0])
    
    # Plot the light curve and its Fourier Transform
    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title(title, fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(freqs, np.abs(mag_fft), color='green')
    plt.xlabel('Frequency', fontsize=12)
    plt.ylabel('Magnitude FFT', fontsize=12)
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Path to the .txt file
txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam2_ccd3\lc_discovery\lc_2020kyi_cleaned.txt"
# Specify the delimiter used in the .txt file
delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
# Specify the title
title = "2020kyi"  # Change this to the appropriate title
# Plot the light curve with the specified title
plot_light_curve_with_fft(txt_file, delimiter, title)

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020lkf', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam4_ccd1\lc_discovery\lc_2020lkf_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020kav', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam2_ccd3\lc_discovery\lc_2020kav_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020ltf', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam2_ccd1\lc_discovery\lc_2020ltf_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020liy', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam1_ccd4\lc_discovery\lc_2020liy_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

#Possible Nova Event characterized by the sharp rise in magnitude and gradual decrease after

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020klw', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam1_ccd1\lc_discovery\lc_2020klw_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020lpz', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam3_ccd4\lc_discovery\lc_2020lpz_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()
    
#From TNS- BL Lac 8C 1803+784 brightens by 0.8 mag in 1 month

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020kbo', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam2_ccd1\lc_discovery\lc_2020kbo_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020lfw', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector25\cam1_ccd2\lc_discovery\lc_2020lfw_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

#From TNS- "See arXiv:1904.05922 for selection criteria."
