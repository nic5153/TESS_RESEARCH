# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jhe', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam3_ccd1\lc_discovery\lc_2020jhe_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

#This curve is likely an eclipsing binary system
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 42
#      39     plot_light_curve(txt_file, delimiter)
#      41 if __name__ == "__main__":
# ---> 42     main()
#
# Cell In[3], line 39, in main()
#      36 delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
#      37 # Specify the title
#      38 # Plot the light curve with the specified title
# ---> 39 plot_light_curve(txt_file, delimiter)
#
# Cell In[3], line 8, in plot_light_curve(txt_file, delimiter, title)
#       5 def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
#       6     # Read the .txt file into a DataFrame
#       7     try:
# ----> 8         df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
#       9     except pd.errors.EmptyDataError:
#      10         print(f"The file '{txt_file}' is empty.")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\nic51\\TESS RESEARCH\\Extracted_tarballs\\sector24\\cam3_ccd1\\lc_discovery\\lc_2020jhe_cleaned.txt'

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020ilw', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam1_ccd1\lc_discovery\lc_2020ilw_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# from TNS- "known CV V844 Her in 4 mag outburst"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4, in plot_light_curve(txt_file, delimiter, title)
#       3 try:
# ----> 4     df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
#       5 except pd.errors.EmptyDataError:
#
# NameError: name 'pd' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 38
#      35     plot_light_curve(txt_file, delimiter)
#      37 if __name__ == "__main__":
# ---> 38     main()
#
# Cell In[1], line 35, in main()
#      32 delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
#      33 # Specify the title
#      34 # Plot the light curve with the specified title
# ---> 35 plot_light_curve(txt_file, delimiter)
#
# Cell In[1], line 5, in plot_light_curve(txt_file, delimiter, title)
#       3 try:
#       4     df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
# ----> 5 except pd.errors.EmptyDataError:
#       6     print(f"The file '{txt_file}' is empty.")
#       7     return
#
# NameError: name 'pd' is not defined

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020ish', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam2_ccd4\lc_discovery\lc_2020ish_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()
    
    #possible CV
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4, in plot_light_curve(txt_file, delimiter, title)
#       3 try:
# ----> 4     df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
#       5 except pd.errors.EmptyDataError:
#
# NameError: name 'pd' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 38
#      35     plot_light_curve(txt_file, delimiter)
#      37 if __name__ == "__main__":
# ---> 38     main()
#
# Cell In[2], line 35, in main()
#      32 delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
#      33 # Specify the title
#      34 # Plot the light curve with the specified title
# ---> 35 plot_light_curve(txt_file, delimiter)
#
# Cell In[2], line 5, in plot_light_curve(txt_file, delimiter, title)
#       3 try:
#       4     df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
# ----> 5 except pd.errors.EmptyDataError:
#       6     print(f"The file '{txt_file}' is empty.")
#       7     return
#
# NameError: name 'pd' is not defined

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020juf', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam1_ccd2\lc_discovery\lc_2020juf_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jvr', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam4_ccd4\lc_discovery\lc_2020jvr_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# From TNS- brightening in erratic YSO (young stellar object, a.k.a new born star)

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jkj', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam4_ccd2\lc_discovery\lc_2020jkj_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# Classified as a Variable Star (?)

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jvc', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam4_ccd3\lc_discovery\lc_2020jvc_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

#From TNS- 2.5 mag rise in erratic Gaia source

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jss', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam4_ccd3\lc_discovery\lc_2020jss_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jem', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam2_ccd2\lc_discovery\lc_2020jem_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jvg', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam4_ccd4\lc_discovery\lc_2020jvg_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020jsv', fontsize=16)  # Increase the font size of the title
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector24\cam4_ccd3\lc_discovery\lc_2020jsv_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    # Plot the light curve with the specified title
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()
