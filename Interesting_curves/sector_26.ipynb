# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020nmt', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam1_ccd2\lc_discovery\lc_2020nmt_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def plot_light_curve(txt_file, delimiter=r"\s+", title="Light Curve"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title(title, fontsize=16)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam1_ccd2\lc_discovery\lc_2020nhc_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Specify the title
    title = '2020nhc'
    # Plot the light curve
    plot_light_curve(txt_file, delimiter, title)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020nww', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam4_ccd1\lc_discovery\lc_2020nww_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('202nsf', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam3_ccd1\lc_discovery\lc_2020nsf_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020nkf', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam4_ccd1\lc_discovery\lc_2020nkf_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020nle', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam3_ccd3\lc_discovery\lc_2020nle_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()
    
    
print("I think this is a Supernova Type 1")
# Out:
# I think this is a Supernova Type 1

# %%
def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020mqq', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam1_ccd3\lc_discovery\lc_2020mqq_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020nbr', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam1_ccd3\lc_discovery\lc_2020nbr_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()

# %%
def plot_light_curve(txt_file, delimiter=r"\s+"):
    # Read the .txt file into a DataFrame
    try:
        df = pd.read_csv(txt_file, delimiter=delimiter, skiprows=2, header=None, usecols=[1,4], names=['Time', 'Magnitude'])
    except pd.errors.EmptyDataError:
        print(f"The file '{txt_file}' is empty.")
        return
    except pd.errors.ParserError:
        print(f"Error parsing '{txt_file}'. Please check the file format.")
        return

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['Time'], df['Magnitude'])
    line = slope * df['Time'] + intercept
    
    # Plot the light curve
    plt.figure(figsize=(10, 5))
    plt.plot(df['Time'], df['Magnitude'], marker='o', linestyle='-', color='blue', label='Light Curve')
    plt.plot(df['Time'], line, color='red', label='Line of Best Fit')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Magnitude', fontsize=12)
    plt.title('2020ocu', fontsize=14)
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend()
    plt.show()

def main():
    # Path to the .txt file
    txt_file = r"C:\Users\nic51\TESS RESEARCH\Extracted_tarballs\sector26\cam1_ccd1\lc_discovery\lc_2020ocu_cleaned.txt"
    # Specify the delimiter used in the .txt file
    delimiter = r"\s+"  # Change this to the appropriate delimiter (e.g., ',', ' ', etc.)
    # Plot the light curve
    plot_light_curve(txt_file, delimiter)

if __name__ == "__main__":
    main()
